# %%
import glob
import openpyxl
import pandas as pd

appended_project_data = []
appended_results_data = []

path = "/dbfs/mnt/geochem/samples/*"
files = glob.glob(path)

for file in files:
  print(file)
  wb = openpyxl.load_workbook(file)
  sheets = wb.sheetnames
  
  for sheet in sheets:
    print(sheet)
    
    #read the data sheet into a dataframe
    ws = wb[sheet]
    data = ws.values
    columns = next(data)[0:]
    initial_wheader_df = pd.DataFrame(data, columns=columns)
    
    #add the sheename as a column in the dataframe (representing the sample)
    initial_wheader_df['Sample Type']=sheet
    initial_wheader_df = initial_wheader_df[initial_wheader_df['Sample ID'].notnull()]

    #preserve original initial copy of the dataframe
    full_copy_df = initial_wheader_df.copy()
    Project_df =  full_copy_df[['Sample ID','Project Name','Sample Type','Material Type','Lithology','Zone','Borehole']]

    #create a dataframe with the tombstone info
    columns = ['Project Name','Sample Type','Material Type','Lithology','Zone','Borehole']
    results_df = full_copy_df.copy()
    results_df.drop(columns, inplace=True, axis=1)
    
    #unpivot the remaining columns as Test and results using the Sample ID as the index
    results_df = pd.melt(results_df, id_vars=[('Sample ID')],var_name='Test')

    #ensure the Sample ID is unique 
    assert results_df['Sample ID'].duplicated().any()==False
    assert Project_df['Sample ID'].duplicated().any()==False
    
    #keep appending the dataframe to previously loaded dataframes (at the sheet level)
    appended_results_data.append(results_df)
    appended_project_data.append(Project_df)

#keep appending the dataframe to previously loaded dataframes (at the excel file level)
appended_results_df = pd.concat(appended_results_data)
appended_project_df = pd.concat(appended_project_data)
 
#finallly join the two dataframes (projects and results) based on sample id
final_df=pd.merge(appended_project_df,appended_results_df,on='Sample ID', how='left')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/dbfs/mnt/geochem/samples/Beaver Dam_ABASFETRM_Sharing.xlsx
# TRM_aquaregia
# ABA
# SFE
# /dbfs/mnt/geochem/samples/Brucejack _ABATRMSFE_Sharing.xlsx
# ABA
# TRM_aquaregia
# SFE
# /dbfs/mnt/geochem/samples/Cote_ABATRMNAGXRFSFESPLP_Sharing.xlsx
# ABA
# TRM_aquaregia
# TRM_4acid
# NAG
# XRF
# SFE
# SPLP
# </div>

# %%
final_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sample ID</th>
#       <th>Project Name</th>
#       <th>Sample Type</th>
#       <th>Material Type</th>
#       <th>Lithology</th>
#       <th>Zone</th>
#       <th>Borehole</th>
#       <th>Test</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>LX17-12</td>
#       <td>BeaverDam</td>
#       <td>TRM_aquaregia</td>
#       <td>MineRock</td>
#       <td>ARGILLITE</td>
#       <td>None</td>
#       <td>BD14-186</td>
#       <td>Start_m</td>
#       <td>149</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>LX17-12</td>
#       <td>BeaverDam</td>
#       <td>TRM_aquaregia</td>
#       <td>MineRock</td>
#       <td>ARGILLITE</td>
#       <td>None</td>
#       <td>BD14-186</td>
#       <td>Finish_m</td>
#       <td>150</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>LX17-12</td>
#       <td>BeaverDam</td>
#       <td>TRM_aquaregia</td>
#       <td>MineRock</td>
#       <td>ARGILLITE</td>
#       <td>None</td>
#       <td>BD14-186</td>
#       <td>Length_m</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>LX17-12</td>
#       <td>BeaverDam</td>
#       <td>TRM_aquaregia</td>
#       <td>MineRock</td>
#       <td>ARGILLITE</td>
#       <td>None</td>
#       <td>BD14-186</td>
#       <td>Grain Size</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>LX17-12</td>
#       <td>BeaverDam</td>
#       <td>TRM_aquaregia</td>
#       <td>MineRock</td>
#       <td>ARGILLITE</td>
#       <td>None</td>
#       <td>BD14-186</td>
#       <td>AR-Ag_mg/kg</td>
#       <td>-0.2</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>961704</th>
#       <td>CND1(CN-18MC-13-03)</td>
#       <td>Côté</td>
#       <td>SPLP</td>
#       <td>Tailings</td>
#       <td>Composite</td>
#       <td>None</td>
#       <td>None</td>
#       <td>SPLP-Zn_mg/L</td>
#       <td>-0.001</td>
#     </tr>
#     <tr>
#       <th>961705</th>
#       <td>CND1(CN-18MC-13-03)</td>
#       <td>Côté</td>
#       <td>SPLP</td>
#       <td>Tailings</td>
#       <td>Composite</td>
#       <td>None</td>
#       <td>None</td>
#       <td>SPLP-Zr_mg/L</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>961706</th>
#       <td>CND1(CN-18MC-13-03)</td>
#       <td>Côté</td>
#       <td>SPLP</td>
#       <td>Tailings</td>
#       <td>Composite</td>
#       <td>None</td>
#       <td>None</td>
#       <td>SPLP-NH3_mg/L</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>961707</th>
#       <td>CND1(CN-18MC-13-03)</td>
#       <td>Côté</td>
#       <td>SPLP</td>
#       <td>Tailings</td>
#       <td>Composite</td>
#       <td>None</td>
#       <td>None</td>
#       <td>SPLP-NH4_mg/L</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>961708</th>
#       <td>CND1(CN-18MC-13-03)</td>
#       <td>Côté</td>
#       <td>SPLP</td>
#       <td>Tailings</td>
#       <td>Composite</td>
#       <td>None</td>
#       <td>None</td>
#       <td>SPLP-NH3+NH4_mg/l</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# <p>961709 rows × 9 columns</p>
# </div>

# %% [markdown]
# ####Convert the Pandas Dataframe to Spark Dataframe for downstream processing

# %%
final_df[['Sample ID','Project Name','Sample Type','Material Type','Lithology','Zone','Borehole','Test','value']] = final_df[['Sample ID','Project Name','Sample Type','Material Type','Lithology',	'Zone','Borehole','Test','value']].astype(str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark_final_results_df = spark.createDataFrame(final_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ####Create a temporary view from the dataframe

# %%
spark_final_results_df.createOrReplaceTempView("tempvwresults")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[82]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sample ID</th>
#       <th>Project Name</th>
#       <th>Sample Type</th>
#       <th>Material Type</th>
#       <th>Lithology</th>
#       <th>Zone</th>
#       <th>Borehole</th>
#       <th>Test</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>LX17-12</td>
#       <td>BeaverDam</td>
#       <td>TRM_aquaregia</td>
#       <td>MineRock</td>
#       <td>ARGILLITE</td>
#       <td>None</td>
#       <td>BD14-186</td>
#       <td>Start_m</td>
#       <td>149</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>LX17-12</td>
#       <td>BeaverDam</td>
#       <td>TRM_aquaregia</td>
#       <td>MineRock</td>
#       <td>ARGILLITE</td>
#       <td>None</td>
#       <td>BD14-186</td>
#       <td>Finish_m</td>
#       <td>150</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>LX17-12</td>
#       <td>BeaverDam</td>
#       <td>TRM_aquaregia</td>
#       <td>MineRock</td>
#       <td>ARGILLITE</td>
#       <td>None</td>
#       <td>BD14-186</td>
#       <td>Length_m</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>LX17-12</td>
#       <td>BeaverDam</td>
#       <td>TRM_aquaregia</td>
#       <td>MineRock</td>
#       <td>ARGILLITE</td>
#       <td>None</td>
#       <td>BD14-186</td>
#       <td>Grain Size</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>LX17-12</td>
#       <td>BeaverDam</td>
#       <td>TRM_aquaregia</td>
#       <td>MineRock</td>
#       <td>ARGILLITE</td>
#       <td>None</td>
#       <td>BD14-186</td>
#       <td>AR-Ag_mg/kg</td>
#       <td>-0.2</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>961704</th>
#       <td>SU-114-001</td>
#       <td>Brucejack</td>
#       <td>SFE</td>
#       <td>WasteRock</td>
#       <td>SilicifiedBreccia</td>
#       <td>TheValleyofKings(VOK)OreZone</td>
#       <td>None</td>
#       <td>SFE-Zn_mg/L</td>
#       <td>-0.001</td>
#     </tr>
#     <tr>
#       <th>961705</th>
#       <td>SU-114-001</td>
#       <td>Brucejack</td>
#       <td>SFE</td>
#       <td>WasteRock</td>
#       <td>SilicifiedBreccia</td>
#       <td>TheValleyofKings(VOK)OreZone</td>
#       <td>None</td>
#       <td>SFE-Zr_mg/L</td>
#       <td>1e-05</td>
#     </tr>
#     <tr>
#       <th>961706</th>
#       <td>SU-114-001</td>
#       <td>Brucejack</td>
#       <td>SFE</td>
#       <td>WasteRock</td>
#       <td>SilicifiedBreccia</td>
#       <td>TheValleyofKings(VOK)OreZone</td>
#       <td>None</td>
#       <td>SFE-NH3_mg/L</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>961707</th>
#       <td>SU-114-001</td>
#       <td>Brucejack</td>
#       <td>SFE</td>
#       <td>WasteRock</td>
#       <td>SilicifiedBreccia</td>
#       <td>TheValleyofKings(VOK)OreZone</td>
#       <td>None</td>
#       <td>SFE-NH4_mg/L</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>961708</th>
#       <td>SU-114-001</td>
#       <td>Brucejack</td>
#       <td>SFE</td>
#       <td>WasteRock</td>
#       <td>SilicifiedBreccia</td>
#       <td>TheValleyofKings(VOK)OreZone</td>
#       <td>None</td>
#       <td>SFE-NH3+NH4_mg/l</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# <p>961709 rows × 9 columns</p>
# </div>

# %% [markdown]
# ####Store the data into a delta lake table

# %%
# %sql
TRUNCATE TABLE GEOCHEM.PROJECT_SAMPLE_TEST_RESULT;

INSERT INTO GEOCHEM.PROJECT_SAMPLE_TEST_RESULT (SELECT * FROM tempvwresults)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Use SQL to analyze the data

# %%
# %sql
SELECT distinct PROJECT_NM,SAMPLE_TYPE_LBL FROM GEOCHEM.PROJECT_SAMPLE_TEST_RESULT;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PROJECT_NM</th><th>SAMPLE_TYPE_LBL</th></tr></thead><tbody><tr><td>BeaverDam</td><td>ABA</td></tr><tr><td>Côté</td><td>ABA</td></tr><tr><td>BeaverDam</td><td>SFE</td></tr><tr><td>BeaverDam</td><td>TRM_aquaregia</td></tr><tr><td>null</td><td>null</td></tr><tr><td>Côté</td><td>TRM_4acid</td></tr><tr><td>Côté</td><td>NAG</td></tr><tr><td>Côté</td><td>TRM_aquaregia</td></tr><tr><td>Côté</td><td>SFE</td></tr><tr><td>Côté</td><td>SPLP</td></tr><tr><td>Côté</td><td>XRF</td></tr><tr><td>Brucejack</td><td>ABA</td></tr><tr><td>Brucejack</td><td>TRM_aquaregia</td></tr><tr><td>Brucejack</td><td>SFE</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM GEOCHEM.PROJECT_SAMPLE_TEST_RESULT
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SAMPLE_ID</th><th>Project_NM</th><th>Sample_Type_LBL</th><th>Material_Type_LBL</th><th>Lithology_LBL</th><th>Zone_LBL</th><th>Borehole_LBL</th><th>Test_NM</th><th>Value_SRT</th></tr></thead><tbody><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>Start_m</td><td>149.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>Finish_m</td><td>150.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>Length_m</td><td>None</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>Grain Size</td><td>None</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Ag_mg/kg</td><td>-0.2</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Al_mg/kg</td><td>27400.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Au_mg/kg</td><td>None</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-As_mg/kg</td><td>17.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-B_mg/kg</td><td>-10.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Ba_mg/kg</td><td>90.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Be_mg/kg</td><td>0.5</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Bi_mg/kg</td><td>-2.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Br_mg/kg</td><td>None</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Ca_mg/kg</td><td>2000.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Cd_mg/kg</td><td>-0.5</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Ce_mg/kg</td><td>None</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Cl_mg/kg</td><td>None</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Co_mg/kg</td><td>20.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Cr_mg/kg</td><td>41.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Cs_mg/kg</td><td>None</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Cu_mg/kg</td><td>28.0</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Dy_mg/kg</td><td>None</td></tr><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None ...

# %%
# %sql
select Project_NM,count(*) from GEOCHEM.PROJECT_SAMPLE_TEST_RESULT where Project_NM is not null
group by Project_NM
Order by count(*)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Project_NM</th><th>count(1)</th></tr></thead><tbody><tr><td>BeaverDam</td><td>22883</td></tr><tr><td>Brucejack</td><td>227352</td></tr><tr><td>Côté</td><td>711474</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM GEOCHEM.PROJECT_SAMPLE_TEST_RESULT
WHERE SAMPLE_TYPE_LBL ='TRM_aquaregia' 
  AND Test_NM = 'AR-Fe_mg/kg'
  AND Value_SRT > 1700
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SAMPLE_ID</th><th>Project_NM</th><th>Sample_Type_LBL</th><th>Material_Type_LBL</th><th>Lithology_LBL</th><th>Zone_LBL</th><th>Borehole_LBL</th><th>Test_NM</th><th>Value_SRT</th></tr></thead><tbody><tr><td>LX17-12</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>45700.0</td></tr><tr><td>LX17-22</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>24800.0</td></tr><tr><td>LX17-24</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>48500.0</td></tr><tr><td>LX17-02</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE-GREYWACKE</td><td>None</td><td>BD15-GT02</td><td>AR-Fe_mg/kg</td><td>62200.0</td></tr><tr><td>LX17-03</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE-GREYWACKE</td><td>None</td><td>BD15-GT02</td><td>AR-Fe_mg/kg</td><td>53000.0</td></tr><tr><td>LX17-04</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE-GREYWACKE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>61600.0</td></tr><tr><td>LX17-09</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE-GREYWACKE</td><td>None</td><td>BD14-160</td><td>AR-Fe_mg/kg</td><td>50900.0</td></tr><tr><td>LX17-10</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE-GREYWACKE</td><td>None</td><td>BD14-160</td><td>AR-Fe_mg/kg</td><td>44500.0</td></tr><tr><td>LX17-11</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE-GREYWACKE</td><td>None</td><td>BD14-160</td><td>AR-Fe_mg/kg</td><td>54000.0</td></tr><tr><td>LX17-13</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE-GREYWACKE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>48400.0</td></tr><tr><td>LX17-28</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>ARGILLITE-GREYWACKE</td><td>None</td><td>BD14-173</td><td>AR-Fe_mg/kg</td><td>48500.0</td></tr><tr><td>LX17-01</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>GREYWACKE-ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>30600.0</td></tr><tr><td>LX17-05</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>GREYWACKE-ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>45400.0</td></tr><tr><td>LX17-07</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>GREYWACKE-ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>56500.0</td></tr><tr><td>LX17-14</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>GREYWACKE-ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>38100.0</td></tr><tr><td>LX17-15</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>GREYWACKE-ARGILLITE</td><td>None</td><td>BD14-160</td><td>AR-Fe_mg/kg</td><td>38500.0</td></tr><tr><td>LX17-17</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>GREYWACKE-ARGILLITE</td><td>None</td><td>BD14-160</td><td>AR-Fe_mg/kg</td><td>36300.0</td></tr><tr><td>LX17-18</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>GREYWACKE-ARGILLITE</td><td>None</td><td>BD14-160</td><td>AR-Fe_mg/kg</td><td>15000.0</td></tr><tr><td>LX17-19</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>GREYWACKE-ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>51200.0</td></tr><tr><td>LX17-23</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>GREYWACKE-ARGILLITE</td><td>None</td><td>BD14-186</td><td>AR-Fe_mg/kg</td><td>32800.0</td></tr><tr><td>LX17-29</td><td>BeaverDam</td><td>TRM_aquaregia</td><td>MineRock</td><td>GREYWACKE-ARGILLITE</td><td>None</td><td>BD14-160</td><td>AR-Fe_mg/kg</td><td>39100.0</td></tr><tr><td>LX17-06< ...

# %%
# %sql

CREATE SCHEMA GEOCHEM;

CREATE TABLE GEOCHEM.PROJECT_SAMPLE_TEST_RESULT (
SAMPLE_ID string,
Project_NM string,
Sample_Type_LBL string,
Material_Type_LBL string,
Lithology_LBL string,
Zone_LBL string,
Borehole_LBL string,
Test_NM string,
Value_SRT string
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
